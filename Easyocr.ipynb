# %%
import matplotlib.pyplot as plt
import easyocr
import cv2

# %%
reader = easyocr.Reader(['en'], detector='DB', recognizer = 'Transformer')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
img = cv2.imread("images/text_en.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
result = reader.readtext(img)

# %%
plt.imshow(img)
plt.show()
for i in result:
    print(i[1], end=" ")
# Out:
# Write Everyday Edited Nov . Call me Ishmael. Some years ago-never mind how long precisely_ having little money in my purse, and nothing particular interest on  shore, I thought I would sail about little and see the watery part of the world. It is a way have of driving off the spleen and regulating the circulation. Whenever I find myself growing grim about the mouth; whenever it is damp, drizzly November soul; whenever find myself involuntarily pausing before coffin warehouses , and bringing the rear of every funeral meet; and especially whenever my hypos get such an upper hand of me, that it requires strong moral principle prevent from deliberatelv stepping into the street , and

# %%
reader = easyocr.Reader(['ru', 'en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
img2 = cv2.imread("images/Russian_numbers.png")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
result = reader.readtext(img2)

# %%
plt.imshow(img2)
plt.show()
for i in result:
    print(i[1])
# Out:
# How 10 Count in Russian
# zero
# one
# 0
# ноль
# один
# nol'
# odin
# three
# 2
# два
# три
# 3
# dva
# tri
# four
# five
# 4
# четыре
# пять
# 5
# chetyre
# six
# seven
# 6
# шесть
# семь
# shest'
# sem
# eight
# nine
# c
# восемь
# девять
# vosem'
# devyat'
# RussianPod10l com
# two
# pyat'

# %%
# !pip install aiogram
# Out:
# Collecting aiogram
#   Downloading aiogram-3.6.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting aiofiles~=23.2.1 (from aiogram)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting aiohttp~=3.9.0 (from aiogram)
#   Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: certifi>=2023.7.22 in /home/nurik/Programms/ImageToText/ittenv/lib/python3.11/site-packages (from aiogram) (2024.2.2)
# Collecting magic-filter<1.1,>=1.0.12 (from aiogram)
#   Downloading magic_filter-1.0.12-py3-none-any.whl.metadata (1.5 kB)
# Collecting pydantic<2.8,>=2.4.1 (from aiogram)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 1.2 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions<=5.0,>=4.7.0 in /home/nurik/Programms/ImageToText/ittenv/lib/python3.11/site-packages (from aiogram) (4.11.0)
# Collecting aiosignal>=1.1.2 (from aiohttp~=3.9.0->aiogram)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/nurik/Programms/ImageToText/ittenv/lib/python3.11/site-packages (from aiohttp~=3.9.0->aiogram) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.9.0->aiogram)
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.9.0->aiogram)
#   Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp~=3.9.0->aiogram)
#   Downloading yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<2.8,>=2.4.1->aiogram)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<2.8,>=2.4.1->aiogram)
#   Downloading pydantic_core-2.18.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: idna>=2.0 in /home/nurik/Programms/ImageToText/ittenv/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp~=3.9.0->aiogram) (3.6)
# Downloading aiogram-3.6.0-py3-none-any.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 2.3 MB/s eta 0:00:000:00:010:00:01:01
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.7 MB/s eta 0:00:002.8 MB/s eta 0:00:01
# Downloading magic_filter-1.0.12-py3-none-any.whl (11 kB)
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 4.6 MB/s eta 0:00:000:00:010:00:01
# Downloading pydantic_core-2.18.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 3.2 MB/s eta 0:00:000:00:010:00:01
# Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 4.2 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.1/328.1 kB 7.2 MB/s eta 0:00:0010.5 MB/s eta 0:00:01
# Installing collected packages: pydantic-core, multidict, magic-filter, frozenlist, annotated-types, aiofiles, yarl, pydantic, aiosignal, aiohttp, aiogram
# Successfully installed aiofiles-23.2.1 aiogram-3.6.0 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.6.0 frozenlist-1.4.1 magic-filter-1.0.12 multidict-6.0.5 pydantic-2.7.1 pydantic-core-2.18.2 yarl-1.9.4
